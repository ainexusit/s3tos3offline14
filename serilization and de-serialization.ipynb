# %%
empdata = {"id":101,
           "name":'test',
           'city': 'pune',
           "isper":False,
           "istemp":None
          }

# %%
import json

# %%
dict/python obj --

1.json string 

    dumps --- python obj to json string

    loads -- json string to dict

2.json file

    dump  --- python obj to json file

# %%
empdata
# Out:
# {'id': 101, 'name': 'test', 'city': 'pune', 'isper': False, 'istemp': None}

# %%
js = json.dumps(empdata)

# %%
json --->   " 

None -- null
False -- false

# %%
js
# Out:
# '{"id": 101, "name": "test", "city": "pune", "isper": false, "istemp": null}'

# %%
json.loads(js)
# Out:
# {'id': 101, 'name': 'test', 'city': 'pune', 'isper': False, 'istemp': None}

# %%
dict  - to - json string -- dumps
json string to dict ---> loads

# %%
empdata
# Out:
# {'id': 101, 'name': 'test', 'city': 'pune', 'isper': False, 'istemp': None}

# %%
with open("emp.json","w") as fp:
    json.dump(empdata,fp)

# %%
with open("emp.json") as fp:
    data = fp.read()
    print(data)
# Out:
# {
#   "employees": [
#     {
#       "id": "EMP001",
#       "firstName": "John",
#       "lastName": "Doe",
#       "email": "john.doe@example.com",
#       "phone": "+1-555-0199",
#       "hireDate": "2022-03-15",
#       "department": "Engineering",
#       "jobTitle": "Software Engineer",
#       "salary": 85000,
#       "status": "Active"
#     },
#     {
#       "id": "EMP002",
#       "firstName": "Jane",
#       "lastName": "Smith",
#       "email": "jane.smith@example.com",
#       "phone": "+1-555-0143",
#       "hireDate": "2021-07-22",
#       "department": "Marketing",
#       "jobTitle": "Marketing Manager",
#       "salary": 78000,
#       "status": "Active"
#     },
#     {
#       "id": "EMP003",
#       "firstName": "Alex",
#       "lastName": "Jones",
#       "email": "alex.jones@example.com",
#       "phone": "+1-555-0177",
#       "hireDate": "2024-01-10",
#       "department": "Human Resources",
#       "jobTitle": "HR Specialist",
#       "salary": 62000,
# ...

# %%
with open("emp.json") as fp:
    data =  json.load(fp)

# %%
data
# Out:
# {'employees': [{'id': 'EMP001',
#    'firstName': 'John',
#    'lastName': 'Doe',
#    'email': 'john.doe@example.com',
#    'phone': '+1-555-0199',
#    'hireDate': '2022-03-15',
#    'department': 'Engineering',
#    'jobTitle': 'Software Engineer',
#    'salary': 85000,
#    'status': 'Active'},
#   {'id': 'EMP002',
#    'firstName': 'Jane',
#    'lastName': 'Smith',
#    'email': 'jane.smith@example.com',
#    'phone': '+1-555-0143',
#    'hireDate': '2021-07-22',
#    'department': 'Marketing',
#    'jobTitle': 'Marketing Manager',
#    'salary': 78000,
#    'status': 'Active'},
#   {'id': 'EMP003',
#    'firstName': 'Alex',
#    'lastName': 'Jones',
#    'email': 'alex.jones@example.com',
#    'phone': '+1-555-0177',
#    'hireDate': '2024-01-10',
#    'department': 'Human Resources',
#    'jobTitle': 'HR Specialist',
#    'salary': 62000,
#    'status': 'Active'}]}

# %%
dumps -- loads

python to json string

loads 

json string to python

======================================

dump -- load

python to json file

json file to python
